# %%
import numpy as np
import os
import IPython.display as ipd
# Importing pandas library
import pandas as pd

import sklearn
import sklearn.preprocessing, sklearn.decomposition, sklearn.svm
from sklearn.model_selection import train_test_split
import sklearn.ensemble
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import accuracy_score

# %%
tracks = pd.read_csv('fma_metadata/tracks.csv',index_col=0,header=[0,1])
#genres = pd.read_csv('data/fma_metadata/genres.csv')
features = pd.read_csv('fma_metadata/features.csv',index_col=0,header=[0,1,2])

# %%
tracks
# Out:
#                       album                                            \
#                    comments         date_created        date_released
# track_id Unnamed: 1_level_2   Unnamed: 2_level_2   Unnamed: 3_level_2
# 2                         0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 3                         0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 5                         0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 10                        0  2008-11-26 01:45:08  2008-02-06 00:00:00
# 20                        0  2008-11-26 01:45:05  2009-01-06 00:00:00
# ...                     ...                  ...                  ...
# 155316                    0  2017-03-30 15:20:35  2017-02-17 00:00:00
# 155317                    0  2017-03-30 15:20:35  2017-02-17 00:00:00
# 155318                    0  2017-03-30 15:20:35  2017-02-17 00:00:00
# 155319                    0  2017-03-30 15:20:35  2017-02-17 00:00:00
# ...

# %%
features[0].columns()
# Out:
# feature           chroma_cens                                        \
# statistics           kurtosis
# number                     01                 02                 03
# track_id   Unnamed: 1_level_3 Unnamed: 2_level_3 Unnamed: 3_level_3
# 2                    7.180653           5.230309           0.249321
# 3                    1.888963           0.760539           0.345297
# 5                    0.527563          -0.077654          -0.279610
# 10                   3.702245          -0.291193           2.196742
# 20                  -0.193837          -0.198527           0.201546
# ...                       ...                ...                ...
# 155316              -0.490129           0.463834           2.321970
# 155317              -0.461559          -0.229601          -0.496632
# 155318               0.552473          -0.110498          -0.532014
# 155319              -0.176901           0.187208          -0.050664
# ...

# %%
ipd.display(tracks['track'].head())
ipd.display(tracks['album'].head())
ipd.display(tracks['artist'].head())
ipd.display(tracks['set'].head())
# Out:
#                     bit_rate            comments            composer  \
# track_id Unnamed: 33_level_2 Unnamed: 34_level_2 Unnamed: 35_level_2
# 2                     256000                   0                 NaN
# 3                     256000                   0                 NaN
# 5                     256000                   0                 NaN
# 10                    192000                   0           Kurt Vile
# 20                    256000                   0                 NaN
#
#                  date_created        date_recorded            duration  \
# track_id  Unnamed: 36_level_2  Unnamed: 37_level_2 Unnamed: 38_level_2
# 2         2008-11-26 01:48:12  2008-11-26 00:00:00                 168
# 3         2008-11-26 01:48:14  2008-11-26 00:00:00                 237
# 5         2008-11-26 01:48:20  2008-11-26 00:00:00                 206
# 10        2008-11-25 17:49:06  2008-11-26 00:00:00                 161
# ...

# %%
ipd.display(features.head().style.format('{:.2f}'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_12612">
#   <thead>
#     <tr>
#       <th class="index_name level0" >feature</th>
#       <th id="T_12612_level0_col0" class="col_heading level0 col0" colspan="84">chroma_cens</th>
#       <th id="T_12612_level0_col84" class="col_heading level0 col84" colspan="84">chroma_cqt</th>
#       <th id="T_12612_level0_col168" class="col_heading level0 col168" colspan="84">chroma_stft</th>
#       <th id="T_12612_level0_col252" class="col_heading level0 col252" colspan="140">mfcc</th>
#       <th id="T_12612_level0_col392" class="col_heading level0 col392" colspan="7">rmse</th>
#       <th id="T_12612_level0_col399" class="col_heading level0 col399" colspan="7">spectral_bandwidth</th>
#       <th id="T_12612_level0_col406" class="col_heading level0 col406" colspan="7">spectral_centroid</th>
#       <th id="T_12612_level0_col413" class="col_heading level0 col413" colspan="49">spectral_contrast</th>
# ...

# %%
features.shape
# Out:
# (106574, 518)

# %%
features.isna().sum()
# Out:
# feature      statistics  number  track_id
# chroma_cens  kurtosis    01      Unnamed: 1_level_3      0
#                          02      Unnamed: 2_level_3      0
#                          03      Unnamed: 3_level_3      0
#                          04      Unnamed: 4_level_3      0
#                          05      Unnamed: 5_level_3      0
#                                                         ..
# zcr          mean        01      Unnamed: 514_level_3    0
#              median      01      Unnamed: 515_level_3    0
#              min         01      Unnamed: 516_level_3    0
#              skew        01      Unnamed: 517_level_3    0
#              std         01      Unnamed: 518_level_3    0
# Length: 518, dtype: int64

# %%
tracks['track']
# Out:
#                     bit_rate            comments            composer  \
# track_id Unnamed: 33_level_2 Unnamed: 34_level_2 Unnamed: 35_level_2
# 2                     256000                   0                 NaN
# 3                     256000                   0                 NaN
# 5                     256000                   0                 NaN
# 10                    192000                   0           Kurt Vile
# 20                    256000                   0                 NaN
# ...                      ...                 ...                 ...
# 155316                320000                   0                 NaN
# 155317                320000                   0                 NaN
# 155318                320000                   0                 NaN
# 155319                320000                   0                 NaN
# 155320                320000                   0                 NaN
#
# ...

# %%
track_ids = tracks.index.tolist()
data_track = tracks.loc[track_ids]

feature_ids = features.index.tolist()
data_features = features.loc[feature_ids]
# Out:
#             album                                                     \
#          comments         date_created        date_released engineer
# track_id
# 2               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5               0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 10              0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 20              0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
# ...           ...                  ...                  ...      ...
# 155316          0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155317          0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155318          0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155319          0  2017-03-30 15:20:35  2017-02-17 00:00:00      NaN
# 155320          0  2017-03-26 16:22:18  2017-03-26 00:00:00      NaN
#
# ...

# %%
hitlist = pd.concat([tracks['track'][['genre_top','listens']], features['mfcc']], axis=1)
grouped_hitlist = hitlist.groupby('genre_top')
genre_list = ['Rock','Experimental','Electronic','Hip-Hop','Folk','Pop','Instrumental']
# scaler = sklearn.preprocessing.StandardScaler()
# scaler.fit_transform(grouped_hitlist)

hitlist
# Out:
#          genre_top  listens  (kurtosis, 01)  (kurtosis, 02)  (kurtosis, 03)  \
# track_id
# 2          Hip-Hop     1293        3.856789        1.541901        0.000816
# 3          Hip-Hop      514        4.296755        1.399977        0.112535
# 5          Hip-Hop     1151        2.624517        2.415293        0.440233
# 10             Pop    50135        5.076893        1.161854        2.095651
# 20             NaN      361       11.880132        4.085320        0.002655
# ...            ...      ...             ...             ...             ...
# 155316        Rock      102        4.895152        5.361988        3.186483
# 155317        Rock      165        0.040857        1.752112        0.442188
# 155318        Rock      168        0.581889       -0.129386        0.662489
# 155319        Rock      294        5.164501        3.716359        2.881116
# 155320         NaN      705        4.619462        1.234909        1.236056
#
# ...

# %%
rock_data = pd.DataFrame(grouped_hitlist.get_group('Rock'))
experimental_data = pd.DataFrame(grouped_hitlist.get_group('Experimental'))
electronic_data = pd.DataFrame(grouped_hitlist.get_group('Electronic'))
hip_Hop_data = pd.DataFrame(grouped_hitlist.get_group('Hip-Hop'))
folk_data = pd.DataFrame(grouped_hitlist.get_group('Folk'))
pop_data = pd.DataFrame(grouped_hitlist.get_group('Pop'))
instrumental_data = pd.DataFrame(grouped_hitlist.get_group('Instrumental'))

# %%
x,y = sklearn.utils.shuffle(track_features,balanced_genres['genre_top'],random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20664\1006952954.py in <module>
# ----> 1 x,y = sklearn.utils.shuffle(track_features,balanced_genres['genre_top'],random_state=42)
#
# NameError: name 'track_features' is not defined

# %%
data.columns
# Out:
# Index(['Unnamed: 47_level_2'], dtype='object', name='track_id')
